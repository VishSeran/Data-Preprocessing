# %%
import pandas as pd
import numpy as np
import requests

# %%
def download(url, fileName):
    response = requests.get(url)
    if response.status_code == 200:
        with open(fileName, "wb") as f:
            f.write( response.content)

# %%
file_path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv'

# %%
download (file_path, "auto.csv")
file_name = "auto.csv"

# %%
df = pd.read_csv(file_name)
df.head(20)
# Out:
#     3    ?  alfa-romero  gas    std   two  convertible  rwd  front   88.6  \
# 0   3    ?  alfa-romero  gas    std   two  convertible  rwd  front   88.6
# 1   1    ?  alfa-romero  gas    std   two    hatchback  rwd  front   94.5
# 2   2  164         audi  gas    std  four        sedan  fwd  front   99.8
# 3   2  164         audi  gas    std  four        sedan  4wd  front   99.4
# 4   2    ?         audi  gas    std   two        sedan  fwd  front   99.8
# 5   1  158         audi  gas    std  four        sedan  fwd  front  105.8
# 6   1    ?         audi  gas    std  four        wagon  fwd  front  105.8
# 7   1  158         audi  gas  turbo  four        sedan  fwd  front  105.8
# 8   0    ?         audi  gas  turbo   two    hatchback  4wd  front   99.5
# 9   2  192          bmw  gas    std   two        sedan  rwd  front  101.2
# 10  0  192          bmw  gas    std  four        sedan  rwd  front  101.2
# 11  0  188          bmw  gas    std   two        sedan  rwd  front  101.2
# ...

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df.columns = headers
df.head(20)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           1                 ?  alfa-romero       gas        std
# 2           2               164         audi       gas        std
# 3           2               164         audi       gas        std
# 4           2                 ?         audi       gas        std
# 5           1               158         audi       gas        std
# 6           1                 ?         audi       gas        std
# 7           1               158         audi       gas      turbo
# 8           0                 ?         audi       gas      turbo
# 9           2               192          bmw       gas        std
# 10          0               192          bmw       gas        std
# 11          0               188          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %%
### Data Preprocessing

# %%
### drop the rows if price is NaN or null

# %%
df.dropna(subset  = ["price"], axis  = 0, inplace = True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
### replace the missing values in normalized-losses column with the column mean

df["normalized-losses"] = pd.to_numeric(df["normalized-losses"], errors = "coerce")

# %%
print(df["normalized-losses"].dtype)
# Out:
# float64

# %% [markdown]
# ### Handling Missing Values

# %%
##get missing values
print(df["normalized-losses"].isnull().sum())
df.head(20)
# Out:
# 40
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3                NaN  alfa-romero       gas        std
# 1           1                NaN  alfa-romero       gas        std
# 2           2              164.0         audi       gas        std
# 3           2              164.0         audi       gas        std
# 4           2                NaN         audi       gas        std
# 5           1              158.0         audi       gas        std
# 6           1                NaN         audi       gas        std
# 7           1              158.0         audi       gas      turbo
# 8           0                NaN         audi       gas      turbo
# 9           2              192.0          bmw       gas        std
# 10          0              192.0          bmw       gas        std
# 11          0              188.0          bmw       gas        std
# 12          0              188.0          bmw       gas        std
# ...

# %%
#mean value of the column
mean = df["normalized-losses"].mean()

# %%
##Sign mean value to  missing values
df["normalized-losses"].fillna(mean, inplace = True)
df.head(20)
# Out:
# C:\Users\Vish\AppData\Local\Temp\ipykernel_16096\3509456301.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["normalized-losses"].fillna(mean, inplace = True)
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3                NaN  alfa-romero       gas        std
# ...

# %%
### covert mpg to L/100km (liters per 100km)

df["city-mpg"] = 235/df["city-mpg"]

#rename the city-mpg tp l/100km
df.rename(columns = {"city-mpg" : "L/100km"}, inplace = True)

###convert highway-mpg to L/100km


df.head(20)
# Out:
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3                NaN  alfa-romero       gas        std
# 1           1                NaN  alfa-romero       gas        std
# 2           2              164.0         audi       gas        std
# 3           2              164.0         audi       gas        std
# 4           2                NaN         audi       gas        std
# 5           1              158.0         audi       gas        std
# 6           1                NaN         audi       gas        std
# 7           1              158.0         audi       gas      turbo
# 8           0                NaN         audi       gas      turbo
# 9           2              192.0          bmw       gas        std
# 10          0              192.0          bmw       gas        std
# 11          0              188.0          bmw       gas        std
# 12          0              188.0          bmw       gas        std
# ...

# %%
print(df.isnull().sum())
# Out:
# symboling             0
# normalized-losses    40
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  0
# stroke                0
# compression-ratio     0
# horsepower            0
# peak-rpm              0
# L/100km               0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
df["highway-mpg"] = 235/df["highway-mpg"]
df.rename(columns = {"highway-mpg" : "highway-L/100km"}, inplace = True)

df.head(20)
# Out:
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3                NaN  alfa-romero       gas        std
# 1           1                NaN  alfa-romero       gas        std
# 2           2              164.0         audi       gas        std
# 3           2              164.0         audi       gas        std
# 4           2                NaN         audi       gas        std
# 5           1              158.0         audi       gas        std
# 6           1                NaN         audi       gas        std
# 7           1              158.0         audi       gas      turbo
# 8           0                NaN         audi       gas      turbo
# 9           2              192.0          bmw       gas        std
# 10          0              192.0          bmw       gas        std
# 11          0              188.0          bmw       gas        std
# 12          0              188.0          bmw       gas        std
# ...

# %%
df["highway-L/100km"].dtype
# Out:
# dtype('float64')

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            1                NaN  alfa-romero       gas        std
# 2            2              164.0         audi       gas        std
# 3            2              164.0         audi       gas        std
# 4            2                NaN         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 199         -1               95.0        volvo       gas        std
# 200         -1               95.0        volvo       gas      turbo
# 201         -1               95.0        volvo       gas        std
# 202         -1               95.0        volvo    diesel      turbo
# 203         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df["price"].head(10)
# Out:
# 0    16500
# 1    16500
# 2    13950
# 3    17450
# 4    15250
# 5    17710
# 6    18920
# 7    23875
# 8        ?
# 9    16430
# Name: price, dtype: str

# %%
df["price"] = pd.to_numeric(df["price"], errors = "coerce")
df["price"].head(10)
# Out:
# 0    16500.0
# 1    16500.0
# 2    13950.0
# 3    17450.0
# 4    15250.0
# 5    17710.0
# 6    18920.0
# 7    23875.0
# 8        NaN
# 9    16430.0
# Name: price, dtype: float64

# %%
df.dropna(subset = ["price"] , axis = 0 , inplace = True)

# %%
df["price"].head(10)
# Out:
# 0     16500.0
# 1     16500.0
# 2     13950.0
# 3     17450.0
# 4     15250.0
# 5     17710.0
# 6     18920.0
# 7     23875.0
# 9     16430.0
# 10    16925.0
# Name: price, dtype: float64

# %%
df.head(20)
# Out:
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3                NaN  alfa-romero       gas        std
# 1           1                NaN  alfa-romero       gas        std
# 2           2              164.0         audi       gas        std
# 3           2              164.0         audi       gas        std
# 4           2                NaN         audi       gas        std
# 5           1              158.0         audi       gas        std
# 6           1                NaN         audi       gas        std
# 7           1              158.0         audi       gas      turbo
# 9           2              192.0          bmw       gas        std
# 10          0              192.0          bmw       gas        std
# 11          0              188.0          bmw       gas        std
# 12          0              188.0          bmw       gas        std
# 13          1                NaN          bmw       gas        std
# ...

# %%
df.head(5)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          1                NaN  alfa-romero       gas        std
# 2          2              164.0         audi       gas        std
# 3          2              164.0         audi       gas        std
# 4          2                NaN         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
### Normalizarion values

## for wheelbase

df["wheel-base"] = (df["wheel-base"]-df["wheel-base"].min())/(df["wheel-base"].max()-df["wheel-base"].min())
df["wheel-base"].head(20)
# Out:
# 0     0.058309
# 1     0.230321
# 2     0.384840
# 3     0.373178
# 4     0.384840
# 5     0.559767
# 6     0.559767
# 7     0.559767
# 9     0.425656
# 10    0.425656
# 11    0.425656
# 12    0.425656
# 13    0.492711
# 14    0.492711
# 15    0.492711
# 16    0.682216
# 17    0.052478
# 18    0.230321
# 19    0.230321
# 20    0.206997
# Name: wheel-base, dtype: float64

# %%
###Binning the price columns into Low, Medium or High

bin = np.linspace(min(df["price"]), max(df["price"]), 4)
group_name = ["Low", "Medium", "High"]

df["price-binned"] = pd.cut(df["price"], bin, labels = group_name, include_lowest = True)
df["price-binned"].head(20)
# Out:
# 0        Low
# 1        Low
# 2        Low
# 3        Low
# 4        Low
# 5        Low
# 6     Medium
# 7     Medium
# 9        Low
# 10       Low
# 11    Medium
# 12    Medium
# 13    Medium
# 14    Medium
# 15      High
# 16      High
# 17       Low
# 18       Low
# 19       Low
# 20       Low
# Name: price-binned, dtype: category
# Categories (3, str): ['Low' < 'Medium' < 'High']

# %%
df.head(20)
# Out:
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3                NaN  alfa-romero       gas        std
# 1           1                NaN  alfa-romero       gas        std
# 2           2              164.0         audi       gas        std
# 3           2              164.0         audi       gas        std
# 4           2                NaN         audi       gas        std
# 5           1              158.0         audi       gas        std
# 6           1                NaN         audi       gas        std
# 7           1              158.0         audi       gas      turbo
# 9           2              192.0          bmw       gas        std
# 10          0              192.0          bmw       gas        std
# 11          0              188.0          bmw       gas        std
# 12          0              188.0          bmw       gas        std
# 13          1                NaN          bmw       gas        std
# ...

# %%
df["horsepower"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 199    False
# 200    False
# 201    False
# 202    False
# 203    False
# Name: horsepower, Length: 200, dtype: bool

# %%
df["horsepower"] = pd.to_numeric(df["horsepower"], errors="coerce")
mean_horsePower = df["horsepower"].mean()
df["horsepower"].fillna(mean, inplace=True)
df["horsepower"].dtype
# Out:
# C:\Users\Vish\AppData\Local\Temp\ipykernel_16096\1768485114.py:3: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["horsepower"].fillna(mean, inplace=True)
# dtype('float64')

# %%
bin_horsepower = np.linspace(min(df["horsepower"]), max(df["horsepower"]), 4)
group_horsePower = ["Low", "Medium", "High"]
df["horsepower-binned"] = pd.cut(df["horsepower"], bin_horsepower, labels=group_horsePower, include_lowest=True)
df["horsepower-binned"].head(10)
# Out:
# 0        Low
# 1     Medium
# 2        Low
# 3        Low
# 4        Low
# 5        Low
# 6        Low
# 7     Medium
# 9        Low
# 10       Low
# Name: horsepower-binned, dtype: category
# Categories (3, str): ['Low' < 'Medium' < 'High']

# %%
df.head(10)
# Out:
#     symboling  normalized-losses         make fuel-type aspiration  \
# 0           3                NaN  alfa-romero       gas        std
# 1           1                NaN  alfa-romero       gas        std
# 2           2              164.0         audi       gas        std
# 3           2              164.0         audi       gas        std
# 4           2                NaN         audi       gas        std
# 5           1              158.0         audi       gas        std
# 6           1                NaN         audi       gas        std
# 7           1              158.0         audi       gas      turbo
# 9           2              192.0          bmw       gas        std
# 10          0              192.0          bmw       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0           two  convertible          rwd           front    0.058309  ...
# 1           two    hatchback          rwd           front    0.230321  ...
# ...

# %% [markdown]
# ## One-hot encoding

# %%
## we use pd.get_dummy() for easily convert a feature into one-hot encoding

print(pd.get_dummies(df['fuel-type']))
# Out:
#      diesel    gas
# 0     False   True
# 1     False   True
# 2     False   True
# 3     False   True
# 4     False   True
# ..      ...    ...
# 199   False   True
# 200   False   True
# 201   False   True
# 202    True  False
# 203   False   True
#
# [200 rows x 2 columns]
